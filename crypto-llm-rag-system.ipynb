# %%
import torch
from langchain_community.document_loaders import PyMuPDFLoader,DirectoryLoader
from langchain_community.vectorstores import FAISS
from transformers import AutoTokenizer,AutoModelForCausalLM,pipeline
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from sentence_transformers import CrossEncoder
import os
from langchain_community.retrievers import BM25Retriever
from langchain_classic.retrievers import EnsembleRetriever

# %%
loader=DirectoryLoader('./data/',glob='./*.pdf',loader_cls=PyMuPDFLoader)
docs=loader.load()

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=800,chunk_overlap=160,separators=['\n\n','\n','.',' '])
chunks=text_splitter.split_documents(docs)
len(chunks)
# Out:
# 558

# %%
embeddings=HuggingFaceEmbeddings(model_name='BAAI/bge-small-en-v1.5')
vector_db=FAISS.from_documents(chunks,embeddings)
vector_db.save_local('Vector DB Index')
vector_retriever=vector_db.as_retriever(search_kwargs={'k':15})

# %%
keyword_retriever=BM25Retriever.from_documents(chunks)
keyword_retriever.k=15

# %%
hybrid_retriever=EnsembleRetriever(retrievers=[vector_retriever,keyword_retriever],weights=[0.5,0.5])

# %%
MODEL='Qwen/Qwen2.5-1.5B-Instruct'
tokenizer=AutoTokenizer.from_pretrained(MODEL)
model=AutoModelForCausalLM.from_pretrained(MODEL,device_map='auto',dtype=torch.bfloat16,low_cpu_mem_usage=True)
pipe=pipeline(task='text-generation',temperature=0.4,do_sample=True,tokenizer=tokenizer,model=model,max_new_tokens=512,repetition_penalty=1.1,
              no_repeat_ngram_size=3)
# Out:
# Device set to use cuda:0

# %%
rerank_model=CrossEncoder('cross-encoder/ms-marco-MiniLM-L-6-v2', device='cuda')

# %%
def format_prompt(question):
    initial_search=hybrid_retriever.invoke(question)
    pairs=[[question,doc.page_content] for doc in initial_search]
    scores=rerank_model.predict(pairs)
    scored_results=sorted(zip(scores,initial_search),key=lambda x:x[0],reverse=True)
    final_results=[doc for score,doc in scored_results[:5]]
    context_list=[]

    for doc in final_results:
        file_path=doc.metadata.get('source','unknown')
        filename=os.path.basename(file_path)
        page_num=doc.metadata.get('page',0) + 1
        header=f'[Doc:{filename} | Page:{page_num}]'
        context_list.append(f'{header}\n{doc.page_content}')
        context='\n\n-\n\n'.join(context_list)

        prompt=f'''You are an Experienced Financial Analyst.Your Job is to answer to the question using the CONTEXT provided
         CRITICAL:You must Always cite the source in the format [Doc:filename | Page:X]  Example: [Doc:XYZ.pdf | Page:23] 
         
         IMPORTANT RULES:
         1.The answer must not exceed 500 Words
         2.You must always cite the sources as instructed in the format [Doc:filename | Page:X] 
         3.You must always stick to the information provied in the document 
         4.Make sure you are factually accurate
         5.If the information is not present then say 'No information is present in the document' 
         
         Question:{question}

         Context:{context}

         Answer:'''    
        
        response=pipe(prompt,return_full_text=False)
        return response[0]['generated_text']

# %%
print(format_prompt('What is a VC Focused Prompt?Give an example of it'))
# Out:
#  A VC Focussed Prompt is a strategy where a Long Term Learning Machine (LLM) allocates its resources towards investments in venture capital (VC) funds. This approach aims to capture the potential high returns associated with startups and early-stage companies, which can offer significant growth opportunities over time. Unlike traditional asset allocation strategies, which may focus on more stable or established markets, a VC-focused LLM would prioritize investments in ventures that have the highest probability of achieving substantial growth.
#
# Example:
#
# A hypothetical scenario could involve an LLM allocating a portion of its assets to invest in a diversified pool of VC funds. These funds might include investments in various sectors like technology, healthcare, renewable energy, and consumer goods. By doing so, the LLM is leveraging its learning capabilities to identify promising start-ups and emerging trends before they become mainstream, thereby maximizing the chances of outperforming other investment options within the same timeframe.
#
# In this context, the VC focused prompt serves as a strategic directive guiding the LMM's decision-making process, emphasizing the importance of identifying and investing in innovative and potentially high-growth businesses rather than relying solely on established market benchmarks. This proactive approach allows the LLL to adapt to changing economic landscapes and capitalize on new opportunities that may arise from technological advancements, regulatory changes, or shifts in consumer preferences. Consequently, a well-executed VC-focused strategy by an LLL could lead to superior long-term performance compared to a purely passive or traditional asset-based investment approach.

# %%
print(format_prompt('What are Infra Coins?'))
# Out:
#  InfraCoins are highly functional cryptocurrency assets that facilitate transactions on various blockchain networks. They serve as essential components for utilizing these networks, enabling the execution of digital contracts, and serving as collateral. The term "infrastructure coins" reflects the expansion of blockchain technology beyond Bitcoin into more advanced platforms like Ethereum and other competing systems such as Polkadot and Cardano. These infrastructures are categorized based on their functionality and utility within the broader context of blockchain development. In summary, Infracoins play a crucial role in enhancing the capabilities of blockchain-based systems by providing necessary resources and support for network operations. [Doc:Cryptocurrency Fundamentals.pdf |Page:7]

# %%
print(format_prompt('Explain the complexity of financial decisions?'))
# Out:
#  The complexity of making financial decisions can be understood through the lens of computational demands. According to our proposed framework, which applies to binary choices like whether to use a credit card, complexity arises when individuals have to process multiple pieces of information simultaneously or make decisions under uncertainty. This complexity can lead to errors because people may struggle to weigh different factors effectively.
#
# Our study, conducted with a combined behavioral and visual tracking method, reveals that complexity plays a significant role in influencing these decisions. Specifically, we found that those carrying balances on their cards tend to make more mistakes compared to those without such debts. This suggests that the stakes are higher for them, potentially due to the increased risk associated with carrying debt.
#
# The findings imply that while inattentiveness and low financial literacy might contribute to some errors, they do not fully explain why certain groups make more costly choices. Instead, the complexity inherent in the task itself seems to be a key factor. For example, deciding whether to charge something on a credit account requires evaluating various aspects including interest rates, fees, and repayment options—all of which could be overwhelming for someone trying to make a quick decision.
#
# In essence, our research indicates that complexity acts as a significant barrier to optimal financial decision-making, particularly affecting vulnerable populations who face greater risks when using credit. By understanding this complexity, policymakers and financial institutions can develop strategies to mitigate its impact, perhaps by simplifying processes or providing clearer guidance to help consumers navigate complex financial landscapes more effectively. [Doc:FDCP_ResearchPaper | Page:Citation]
#
# [Doc:CreditCardBehavioralExperiment | Page:Bibliography]

# %%
print(format_prompt('Explain utility tokens , also what is the difference between Blockchain 1.0,Blockchain 2.0 and Blockchain 3.0?'))
# Out:
# Utility tokens are digital assets that are designed to provide utility or functionality within a particular platform or project, rather than being purely investment vehicles. They are distinct from "broken tokens," which are often associated with cryptocurrencies like Bitcoin and Ethereum but lack clear utility. True utility tokens meet certain criteria set by the SEC, including their non-investment nature, fundamental consumption purpose, and proper marketing.
#
# In contrast, Blockchain 2.x refers to the evolution of blockchain technology beyond its initial iteration. This phase saw advancements such as improved scalability, enhanced security features, and more efficient consensus mechanisms. It builds upon the foundational principles established by Blockchain 0.0 (the original blockchain concept) and 1.x (blockchain technologies built on top of existing systems). The focus here was on enhancing the underlying technology without significantly altering its core architecture.
#
# Blockchain 3.x represents the next stage in blockchain development, aiming for even greater efficiency and decentralization. This stage likely involves further innovations in consensus algorithms, smart contract capabilities, and network scaling techniques. Unlike previous iterations, it may prioritize innovation over maintaining compatibility with older blockchains, potentially leading to new standards and protocols that could revolutionize how transactions are processed and verified across distributed networks. However, the exact details and timeline for Blockchain 4.x remain speculative at this point.
#
# The transition from Blockchain 8.x to 9.x would involve substantial changes in blockchain design and implementation, possibly incorporating entirely new paradigms or frameworks. Such a shift might require extensive rethinking of existing infrastructure and could lead to significant disruptions in the industry if not managed carefully. Nonetheless, the goal remains to improve the overall performance, reliability, and user experience of blockchain-based systems. [Doc:BreymartPaper | Page : 6]
#
# [Doc:crypto unified market structure paper.pdf | page:38]

# %%
import joblib
joblib.dump(keyword_retriever,'keyword retriever.pkl')
# Out:
# ['keyword retriever.pkl']
